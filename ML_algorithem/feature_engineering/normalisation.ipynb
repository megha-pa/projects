# %% [markdown]
# ## Normalisation
#
# It is a technique use change the values of numeric column to use common scale without distorting difference in ranges of values or losing information.
#
# Types of Normalisation
# 1.Min-Max scaling- we need to apply Xi=(Xi-Xmin)/(Xmax-Xmin)
# 2.Mean Normalisation
# 3.Max Absolute Scaling
# 4.Robust Scaling
#
# 1.Min Max Scaling-
# xi'=(Xi-Xmin)-(Xmax-Xmin) by applying this on each data you will get values between (0,1)
#
# 2.Mean Normalisation-
# xi'=(Xi-Xmean )-(Xmax-Xmin) mean centrening values between -1 to 1
# if values less than mean -1
# if valus greater than mean 1
#
# 3.Max Absolute Scaling-
# xi'=Xi/|Xmax| if data is sparse means lot of zeros present in data
#
# 4.Robust Scaling
# xi'=(Xi-Xmeadian )-IQR(75 percentile-25 percentile ) it is robust to outliers if data has many outliers
#
# Normalisation vs Standerdisation
#
# 1.1 Is feature Scaling important (based on algorithem working)
# 1.2 Standerdisation most of time used
# 1.3 Normalisation-when sparse data etc

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("social_data.csv")

# %%
df=df.iloc[:,2:]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop('Purchased', axis=1),
                                                    df['Purchased'],
                                                    test_size=0.3,
                                                    random_state=0)

X_train.shape, X_test.shape
# Out:
# ((280, 2), (120, 2))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# fit the scaler to the train set, it will learn the parameters
scaler.fit(X_train)

# transform train and test sets
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

ax1.scatter(X_train['Age'], X_train['EstimatedSalary'])
ax1.set_title("Before Scaling")
ax2.scatter(X_train_scaled['Age'], X_train_scaled['EstimatedSalary'],color='red')
ax2.set_title("After Scaling")
plt.show()
