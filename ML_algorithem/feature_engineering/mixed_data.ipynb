# %% [markdown]
# ## Mixed Variable
# if Column contains both categorical and numerical variable then handling them is difficult ex of mixed variable
#
# Ex C8,E95 etc or if column have both numeric and categorical variable

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/Users/pluto7/Desktop/git_data/ML_algorithem/biv_multi_variate_analysis/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df=pd.read_csv("/Users/pluto7/Desktop/git_data/ML_algorithem/biv_multi_variate_analysis/titanic.csv",usecols=["Cabin","Ticket","Survived"])

# %%
df
# Out:
#      Survived            Ticket Cabin
# 0           0         A/5 21171   NaN
# 1           1          PC 17599   C85
# 2           1  STON/O2. 3101282   NaN
# 3           1            113803  C123
# 4           0            373450   NaN
# ..        ...               ...   ...
# 886         0            211536   NaN
# 887         1            112053   B42
# 888         0        W./C. 6607   NaN
# 889         1            111369  C148
# 890         0            370376   NaN
#
# [891 rows x 3 columns]

# %%
df1=pd.DataFrame({'number':[5,6,8,9,10,"A",8,9,10,"B","G"]})

# %%
df1
# Out:
#    number
# 0       5
# 1       6
# 2       8
# 3       9
# 4      10
# 5       A
# 6       8
# 7       9
# 8      10
# 9       B
# 10      G

# %%
df=df.append(df1)
# Out:
# /var/folders/sl/mghz4g4x4nq06lrj3hn18prw0000gn/T/ipykernel_47795/2128609364.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(df1)

# %%
df
# Out:
#     Survived            Ticket Cabin number
# 0        0.0         A/5 21171   NaN    NaN
# 1        1.0          PC 17599   C85    NaN
# 2        1.0  STON/O2. 3101282   NaN    NaN
# 3        1.0            113803  C123    NaN
# 4        0.0            373450   NaN    NaN
# ..       ...               ...   ...    ...
# 6        NaN               NaN   NaN      8
# 7        NaN               NaN   NaN      9
# 8        NaN               NaN   NaN     10
# 9        NaN               NaN   NaN      B
# 10       NaN               NaN   NaN      G
#
# [902 rows x 4 columns]

# %%
df["number"].unique()
# Out:
# array([nan, 5, 6, 8, 9, 10, 'A', 'B', 'G'], dtype=object)

# %%
fig = df['number'].value_counts().plot.bar()
fig.set_title('Passengers travelling with')
# Out:
# Text(0.5, 1.0, 'Passengers travelling with')

# %%
# extract numerical part
df['number_numerical'] = pd.to_numeric(df["number"],errors='coerce',downcast='integer')

# %%
# extract categorical part
df['number_categorical'] = np.where(df['number_numerical'].isnull(),df['number'],np.nan)

df.tail(20)
# Out:
#      Survived            Ticket Cabin number  number_numerical  \
# 882       0.0              7552   NaN    NaN               NaN
# 883       0.0  C.A./SOTON 34068   NaN    NaN               NaN
# 884       0.0   SOTON/OQ 392076   NaN    NaN               NaN
# 885       0.0            382652   NaN    NaN               NaN
# 886       0.0            211536   NaN    NaN               NaN
# 887       1.0            112053   B42    NaN               NaN
# 888       0.0        W./C. 6607   NaN    NaN               NaN
# 889       1.0            111369  C148    NaN               NaN
# 890       0.0            370376   NaN    NaN               NaN
# 0         NaN               NaN   NaN      5               5.0
# 1         NaN               NaN   NaN      6               6.0
# 2         NaN               NaN   NaN      8               8.0
# 3         NaN               NaN   NaN      9               9.0
# 4         NaN               NaN   NaN     10              10.0
# ...

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df['Ticket'].unique()
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295', 'A/4. 39886', 'PC 17572', '2926',
#        '113509', '19947', 'C.A. 31026', '2697', 'C.A. 34651', 'CA 2144',
#        '2669', '113572', '36973', '347088', 'PC 17605', '2661',
#        'C.A. 29395', 'S.P. 3464', '3101281', '315151', 'C.A. 33111',
#        'S.O.C. 14879', '2680', '1601', '348123', '349208', '374746',
# ...

# %%
##\d Returns a match where the string contains digits (numbers from 0-9)

df['cabin_num'] = df['Cabin'].str.extract('(\d+)') # captures numerical part
df['cabin_cat'] = df['Cabin'].str[0] # captures the first letter

df.head()
# Out:
#    Survived            Ticket Cabin number  number_numerical  \
# 0       0.0         A/5 21171   NaN    NaN               NaN
# 1       1.0          PC 17599   C85    NaN               NaN
# 2       1.0  STON/O2. 3101282   NaN    NaN               NaN
# 3       1.0            113803  C123    NaN               NaN
# 4       0.0            373450   NaN    NaN               NaN
#
#   number_categorical cabin_num cabin_cat
# 0                NaN       NaN       NaN
# 1                NaN        85         C
# 2                NaN       NaN       NaN
# 3                NaN       123         C
# 4                NaN       NaN       NaN

# %%
df['cabin_cat'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 902 entries, 0 to 10
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Survived            891 non-null    float64
#  1   Ticket              891 non-null    object
#  2   Cabin               204 non-null    object
#  3   number              11 non-null     object
#  4   number_numerical    8 non-null      float64
#  5   number_categorical  3 non-null      object
#  6   cabin_num           200 non-null    object
#  7   cabin_cat           204 non-null    object
# dtypes: float64(2), object(6)
# memory usage: 63.4+ KB

# %%
# extract the last bit of ticket as number
df.info()
#df= df[df['Ticket'].notnull()]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 902 entries, 0 to 10
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Survived            891 non-null    float64
#  1   Ticket              891 non-null    object
#  2   Cabin               204 non-null    object
#  3   number              11 non-null     object
#  4   number_numerical    8 non-null      float64
#  5   number_categorical  3 non-null      object
#  6   cabin_num           200 non-null    object
#  7   cabin_cat           204 non-null    object
# dtypes: float64(2), object(6)
# memory usage: 63.4+ KB

# %%
#df=df.fillna("")
df = df[df['Ticket'].notnull()]

# %%
df['ticket_num'] = df['Ticket'].apply(lambda s: s.split()[-1])
df['ticket_num'] = pd.to_numeric(df['ticket_num'],
                                   errors='coerce',
                                   downcast='integer')


# extract the first part of ticket as category
df['ticket_cat'] = df['Ticket'].apply(lambda s: s.split()[0])
df['ticket_cat'] = np.where(df['ticket_cat'].str.isdigit(), np.nan,
                              df['ticket_cat'])

df.head(20)
# Out:
# /var/folders/sl/mghz4g4x4nq06lrj3hn18prw0000gn/T/ipykernel_47795/3827000917.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ticket_num'] = df['Ticket'].apply(lambda s: s.split()[-1])
# /var/folders/sl/mghz4g4x4nq06lrj3hn18prw0000gn/T/ipykernel_47795/3827000917.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ticket_num'] = pd.to_numeric(df['ticket_num'],
# /var/folders/sl/mghz4g4x4nq06lrj3hn18prw0000gn/T/ipykernel_47795/3827000917.py:8: SettingWithCopyWarning:
# ...
